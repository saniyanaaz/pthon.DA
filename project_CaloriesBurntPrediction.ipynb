# %% [markdown]
# <a href="https://colab.research.google.com/github/saniyanaaz/pthon.DA/blob/main/project_CaloriesBurntPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
print(calories_data)
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363       0   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698       1   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863       0   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408       1   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927       1   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082       1   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577       1   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188       1   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037       0   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526       0   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
calories.head(5)
# Out:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0

# %%
calories.tail(5)
# Out:
#         User_ID  Calories
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0

# %%
exercise_data = pd.read_csv("exercise.csv")

# %%
exercise_data.head(5)
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8

# %%
exercise_data.tail(5)
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5

# %%
# combing the two datasets
calories_data= pd.concat((exercise_data, calories["Calories"]),axis =1)

# %%
calories_data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
#checking the shape
calories_data.shape
# Out:
# (15000, 9)

# %%
calories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
#cheaking for missing values
calories_data.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
calories_data.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %% [markdown]
# DATA VIS

# %%
sns.displot(calories_data['Age'])

# %%
plt.scatter(calories_data["Weight"], calories_data["Calories"])
plt.xlabel("Weight")
plt.ylabel("Calories")
plt.title("Relationship between Weight and Calories")
plt.show()

# %%
sns.boxplot(data=calories_data, x="Gender", y="Calories")
plt.xlabel("Gender")
plt.ylabel("Calories")
plt.title("Calories Distribution by Gender")
plt.show()

# %%
sns.distplot(calories_data["Height"])
# Out:
# <ipython-input-121-e82b2767fc99>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calories_data["Height"])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(calories_data["Weight"])
# Out:
# <ipython-input-122-0b74e0c8533f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calories_data["Weight"])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.boxplot(data=calories_data, x="Gender", y="Heart_Rate")
plt.xlabel("Gender")
plt.ylabel("Heart Rate")
plt.title("Heart Rate Distribution by Gender")
plt.show()

# %% [markdown]
# ## **correlation**

# %%
correlation = calories_data.corr()

sns.heatmap(correlation, square=True, annot=True, fmt=".1f", annot_kws={'size': 10})
# Out:
# <ipython-input-124-723ea2018a7f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = calories_data.corr()
# <Axes: >

# %%
calories_data.replace({"Gender":{"male":0,"female":1}},inplace=True)

# %%
X= calories_data.drop(columns=['User_ID',"Calories"], axis=1)
y= calories_data["Calories"]

# %%
print(X)
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0           0   68   190.0    94.0      29.0       105.0       40.8
# 1           1   20   166.0    60.0      14.0        94.0       40.3
# 2           0   69   179.0    79.0       5.0        88.0       38.7
# 3           1   34   179.0    71.0      13.0       100.0       40.5
# 4           1   27   154.0    58.0      10.0        81.0       39.8
# ...       ...  ...     ...     ...       ...         ...        ...
# 14995       1   20   193.0    86.0      11.0        92.0       40.4
# 14996       1   27   165.0    65.0       6.0        85.0       39.2
# 14997       1   43   159.0    58.0      16.0        90.0       40.1
# 14998       0   78   193.0    97.0       2.0        84.0       38.3
# 14999       0   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 7 columns]

# %%
print(y)
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %% [markdown]
# Splitting the data into training data and into test data **bold text**

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (15000, 7) (12000, 7) (3000, 7)

# %%
calories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  int64
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(3)
# memory usage: 1.0 MB

# %%
# Assuming you have a DataFrame called 'calories_data' containing the necessary data
X_train = calories_data[['Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'Gender']]
y = calories_data['Calories']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# Creating and training the linear regression model
linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)

# Predicting on the test set
y_pred = linear_regression.predict(X_test)

# Evaluating the model using mean squared error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 130.08707386188377

# %%
# Calculating the MAE
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 8.385188053147193
